# %% [markdown]
# <a href="https://colab.research.google.com/github/JillianGwyneth/SamplePythonActivities/blob/main/Q1_Narra_FA1_O%C3%B1as_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Determine the distance between two points

import math

x1 = float(input(" Enter x1:"))
x2 = float(input(" Enter x2:"))
y1 = float(input(" Enter y1:"))
y2 = float(input(" Enter y2:"))

#Calculate by using the formula

distance = math.sqrt(math.pow(x2 - x1, 2) + math.pow(y2 - y1, 2))

#Print the final answer

print(f"Distance is: {distance}")

#When using a library, it's more practical because it is faster and easier and helps finding with errors.
# Out:
#  Enter x1:2
#  Enter x2:2
#  Enter y1:6
#  Enter y2:7
# Distance is: 1.0
