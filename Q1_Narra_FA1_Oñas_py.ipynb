# %% [markdown]
# <a href="https://colab.research.google.com/github/JillianGwyneth/SamplePythonActivities/blob/main/Q1_Narra_FA1_O%C3%B1as_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

x1 = int(input("Enter x1:"))
y1 = int(input("Enter y1:"))
x2 = int(input("Enter x2:"))
y2 = int(input("Enter y2:"))

math.sqrt(x2 - x1 , pow(2))
math.sqrt(y2 - y1 , pow(2))
# Out:
# Enter x1:2
# Enter y1:3
# Enter x2:7
# Enter y2:8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_645/1028679848.py in <cell line: 0>()
#       6 y2 = int(input("Enter y2:"))
#       7
# ----> 8 math.sqrt(x2 - x1 , pow(2))
#       9 math.sqrt(y2 - y1 , pow(2))
#      10
#
# TypeError: pow() missing required argument 'exp' (pos 2)
